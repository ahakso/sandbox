# %%
import pandas as pd

raw = pd.read_parquet("/Users/ahakso/Downloads/AllPrintingsParquetFiles/cards.parquet")

legality = pd.read_parquet("/Users/ahakso/Downloads/AllPrintingsParquetFiles/cardLegalities.parquet")

df = raw.loc[
    lambda df: df.availability.str.contains("arena") & df.colors.str.contains(pat="W|G") | (df.colors == "")
].merge(legality.loc[lambda df: df.standard.apply(lambda x: x is not None), ["uuid", "standard"]], on="uuid")

# %%
raw.head()
# Out:
#          artist                             artistIds asciiName  \
# 0  Pete Venters  d54c4a1a-c0c5-4834-84db-125d341f3ad8      None
# 1  Pete Venters  d54c4a1a-c0c5-4834-84db-125d341f3ad8      None
# 2   Volkan Baǵa  93bec3c0-0260-4d31-8064-5d01efb4153f      None
# 3   Volkan Baǵa  93bec3c0-0260-4d31-8064-5d01efb4153f      None
# 4      Mark Zug  48e2b98c-5467-4671-bd42-4c3746115117      None
#
#   attractionLights availability boosterTypes borderColor cardParts  \
# 0             None  mtgo, paper      default       black      None
# 1             None  mtgo, paper      default       black      None
# 2             None  mtgo, paper      default       black      None
# 3             None  mtgo, paper      default       black      None
# 4             None  mtgo, paper      default       black      None
#
#   colorIdentity colorIndicator colors defense duelDeck  edhrecRank  \
# 0             W           None      W    None     None     23066.0
# 1             W           None      W    None     None     23066.0
# 2             W           None      W    None     None     18092.0
# 3             W           None      W    None     None     18092.0
# 4             W           None      W    None     None     24542.0
#
#    edhrecSaltiness  ...  securityStamp setCode  side signature  \
# 0              NaN  ...           None     10E  None      None
# 1              NaN  ...           None     10E  None      None
# 2             0.12  ...           None     10E  None      None
# 3             0.12  ...           None     10E  None      None
# 4             0.12  ...           None     10E  None      None
#
#                                       sourceProducts subsets       subtypes  \
# 0  {"nonfoil": ["3a10f018-17fe-56a7-91ba-b4bd9867...    None  Human, Cleric
# 1  {"foil": ["c5cd29de-5ec9-5e13-b8eb-40e3a9f79f9...    None  Human, Cleric
# 2  {"nonfoil": ["3210bf43-80f4-5ae4-be77-f6584879...    None          Angel
# 3  {"foil": ["c5cd29de-5ec9-5e13-b8eb-40e3a9f79f9...    None          Angel
# 4  {"nonfoil": ["3210bf43-80f4-5ae4-be77-f6584879...    None
#
#   supertypes                                               text toughness  \
# 0             First strike (This creature deals combat damag...         4
# 1             First strike (This creature deals combat damag...         4
# 2             Flying\nWhen this creature enters, you gain 3 ...         3
# 3             Flying\nWhen this creature enters, you gain 3 ...         3
# 4             Target creature gets +3/+3 and gains flying un...      None
#
#                       type     types                                  uuid  \
# 0  Creature — Human Cleric  Creature  5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c
# 1  Creature — Human Cleric  Creature  b7c19924-b4bf-56fc-aa73-f586e940bd42
# 2         Creature — Angel  Creature  57aaebc1-850c-503d-9f6e-bb8d00d8bf7c
# 3         Creature — Angel  Creature  8fd4e2eb-3eb4-50ea-856b-ef638fa47f8a
# 4                  Sorcery   Sorcery  55bd38ca-dc73-5c06-8f80-a6ddd2f44382
#
#                              variations watermark
# 0  b7c19924-b4bf-56fc-aa73-f586e940bd42      None
# 1  5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c      None
# 2  8fd4e2eb-3eb4-50ea-856b-ef638fa47f8a      None
# 3  57aaebc1-850c-503d-9f6e-bb8d00d8bf7c      None
# 4  c5655330-5131-5f40-9d3e-0549d88c6e9e      None
#
# [5 rows x 79 columns]

# %%
mrs = ['angelic destiny',
'lyra dawnbringer',
'smile at death',
'thunderous velocipede',
'primeval bounty',
'elspeth storm slayer',
'salvation engine',
'overlord of the mistmoors',
'vizier of the menagerie',
'quilled greatwurm',
'sab-sunen luxa embodied',
'ureni the song unending',
'teval arbiter of virtue',
'mimeoplasm revered one',
'mox jasper',]
# print('* ' + '\n* 1 '.join(mrs))

# %% [markdown]
# Additional constraint: I have only collected the following mythic rares:
#
# * 1 angelic destiny
# * 1 lyra dawnbringer
# * 1 smile at death
# * 1 thunderous velocipede
# * 1 primeval bounty
# * 1 elspeth storm slayer
# * 1 salvation engine
# * 1 overlord of the mistmoors
# * 1 vizier of the menagerie
# * 1 quilled greatwurm
# * 1 sab-sunen luxa embodied
# * 1 ureni the song unending
# * 1 teval arbiter of virtue
# * 1 mimeoplasm revered one
# * 1 mox jasper
#
# Do not recommend mythic rares outside of this set.

# %%
cols_to_keep = [
    "name",
    "colorIdentity",
    "manaCost",
    "power",
    "toughness",
    "originalText",
    "type",
    "subtypes",
    "rarity",
]
dedupe = (
    df[cols_to_keep]
    .groupby("name", as_index=False)
    .apply(lambda df: df[cols_to_keep].head(1))
    .drop_duplicates()
    .reset_index(drop=True)
)  # .to_csv("/Users/ahakso/Downloads/candidate_cards.csv", index=False)
# Out:
# /var/folders/pj/00h3gzcx10b6y35kr5_tdc4m0000gp/T/ipykernel_8394/1826221830.py:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda df: df[cols_to_keep].head(1))

# %%
owned_mythics = dedupe.loc[
    lambda df: (df.rarity == "mythic") & (df.name.str.lower().str.replace(",", "").isin(mrs))
].name.unique()
filtered_df = dedupe.loc[lambda df: df.name.isin(owned_mythics) | (df.rarity != "mythic")]

# %%
filtered_df.to_csv("/Users/ahakso/Downloads/candidate_cards.csv",index=False)

# %%
len(filtered_df.to_json(orient='records',index=False))
# Out:
# 659240

# %%
from pyperclip import copy

# %%
for ot in filtered_df.head().originalText.values:
    print(ot+2*'\n')
# Out:
# When A Killer Among Us enters the battlefield, create a 1/1 white Human creature token, a 1/1 blue Merfolk creature token, and a 1/1 red Goblin creature token. Then secretly choose Human, Merfolk, or Goblin.\nSacrifice A Killer Among Us, Reveal the chosen creature type: If target attacking creature token is the chosen type, put three +1/+1 counters on it and it gains deathtouch until end of turn.
#
#
# Enchanted creatures you control get +2/+2.
#
#
# When Aatchik enters, create a 1/1 green Insect creature token for each artifact and/or creature card in your graveyard.\nWhenever another Insect you control dies, put a +1/+1 counter on Aatchik. Each opponent loses 1 life.
#
#
# Abandoned Campground enters tapped unless a player has 13 or less life.\n{T}: Add {W} or {U}.
#
#
# Abraded Bluffs enters the battlefield tapped.\nWhen Abraded Bluffs enters the battlefield, it deals 1 damage to target opponent.\n{T}: Add {R} or {W}.

# %%
copy(filtered_df.to_csv(index=False))

# %%
import pandas as pd
sets = pd.read_parquet("/Users/ahakso/Downloads/AllPrintingsParquetFiles/sets.parquet")

# %%
import pandas as pd
pd.read_parquet("/Users/ahakso/Downloads/AllPrintingsParquetFiles/setTranslations.parquet")
# Out:
#                  language setCode              translation
# 0      Chinese Simplified     10E                     None
# 1     Chinese Traditional     10E                     None
# 2                  French     10E          Dixième édition
# 3                  German     10E           Zehnte Edition
# 4                 Italian     10E          Decima Edizione
# ...                   ...     ...                      ...
# 1455             Japanese     ZNR                     None
# 1456               Korean     ZNR                     None
# 1457  Portuguese (Brazil)     ZNR                     None
# 1458              Russian     ZNR                     None
# 1459              Spanish     ZNR  El resurgir de Zendikar
#
# [1460 rows x 3 columns]

# %%
sets.query("code=='DFT'")#filter(like='code')
# Out:
#      baseSetSize block  cardsphereSetId code  isFoilOnly isForeignOnly  \
# 135          291  None              NaN  DFT       False          None
#
#     isNonFoilOnly  isOnlineOnly isPartialPreview keyruneCode  \
# 135          None         False             None         DFT
#
#                                              languages   mcmId  mcmIdExtras  \
# 135  English, French, German, Italian, Japanese, Sp...  5982.0       6011.0
#
#          mcmName mtgoCode         name parentCode releaseDate  \
# 135  Aetherdrift      DFT  Aetherdrift       None  2025-02-14
#
#      tcgplayerGroupId tokenSetCode  totalSetSize       type
# 135           23874.0         TDFT           553  expansion

# %% [markdown]
# # Export to Gemini

# %%
import pandas as pd

raw = pd.read_parquet("/Users/ahakso/Downloads/AllPrintingsParquetFiles/cards.parquet")

legality = pd.read_parquet("/Users/ahakso/Downloads/AllPrintingsParquetFiles/cardLegalities.parquet")

df = raw.loc[lambda df: df.availability.str.contains("arena")].merge(
    legality.loc[lambda df: df.standard.apply(lambda x: x is not None), ["uuid", "standard"]], on="uuid"
)

# %%
cols_to_keep = [
    "name",
    "rarity",
    "power",
    "toughness",
    "types",
    "type",
    "supertypes",
    "subtypes",
    "setCode",
    "loyalty",
    "life",
    "text",
    "cardParts",
    "colorIdentity",
    "edhrecRank",
    "edhrecSaltiness",
    "faceConvertedManaCost",
    "faceManaValue",
    "faceName",
    "keywords",
    "manaCost",
    "manaValue",
]

# %%
df.loc[:,cols_to_keep].drop_duplicates().to_csv('/Users/ahakso/gd/sandbox/card_data.csv',index=False)

# %%
df.head(3).T
# Out:
#                                                                          0  \
# artist                                       Jana Schirmer & Johannes Voss
# artistIds                64c0582e-949d-41cb-8a23-a25b87850748, 3593dd7e...
# asciiName                                                             None
# attractionLights                                                      None
# availability                                            arena, mtgo, paper
# boosterTypes                                                       default
# borderColor                                                          black
# cardParts                                                             None
# colorIdentity                                                            W
# colorIndicator                                                        None
# colors                                                                   W
# defense                                                               None
# duelDeck                                                              None
# edhrecRank                                                           503.0
# edhrecSaltiness                                                       0.15
# faceConvertedManaCost                                                  NaN
# faceFlavorName                                                        None
# faceManaValue                                                          NaN
# faceName                                                              None
# finishes                                                     nonfoil, foil
# flavorName                                                            None
# flavorText               "In these halls there is no pass or fail. Your...
# frameEffects                                                          None
# frameVersion                                                          2015
# hand                                                                  None
# hasAlternativeDeckLimit                                               None
# hasContentWarning                                                     None
# hasFoil                                                               True
# hasNonFoil                                                            True
# isAlternative                                                         None
# isFullArt                                                             None
# isFunny                                                               None
# isGameChanger                                                         None
# isOnlineOnly                                                          None
# isOversized                                                           None
# isPromo                                                               None
# isRebalanced                                                          None
# isReprint                                                             True
# isReserved                                                            None
# isStarter                                                             None
# isStorySpotlight                                                      None
# isTextless                                                            None
# isTimeshifted                                                         None
# keywords                                                              None
# language                                                           English
# layout                                                              normal
# leadershipSkills                                                      None
# life                                                                  None
# loyalty                                                               None
# manaCost                                                            {2}{W}
# manaValue                                                              3.0
# name                                                    Mentor of the Meek
# number                                                                  17
# originalPrintings                                                     None
# originalReleaseDate                                                   None
# originalText             Whenever another creature with power 2 or less...
# originalType                                      Creature — Human Soldier
# otherFaceIds                                                          None
# power                                                                    2
# printings                2X2, C14, C16, E01, FDN, INR, ISD, J25, JMP, L...
# promoTypes                                                            None
# rarity                                                            uncommon
# rebalancedPrintings                                                   None
# relatedCards                                                          None
# securityStamp                                                         None
# setCode                                                                2X2
# side                                                                  None
# signature                                                             None
# sourceProducts           {"foil": ["66793ae3-270b-5a9f-8a25-15e689c1150...
# subsets                                                               None
# subtypes                                                    Human, Soldier
# supertypes
# text                     Whenever another creature you control with pow...
# toughness                                                                2
# type                                              Creature — Human Soldier
# types                                                             Creature
# uuid                                  73ae97f7-f6a2-587c-9851-3feaa23da4db
# variations                            757e6ffc-f1ec-5ad2-995d-fd09e392b906
# watermark                                                             None
# standard                                                             Legal
#
#                                                                          1  \
# artist                                                        Zoltan Boros
# artistIds                             1885e6cb-c827-4896-994e-3d0a027d602f
# asciiName                                                             None
# attractionLights                                                      None
# availability                                            arena, mtgo, paper
# boosterTypes                                                       default
# borderColor                                                          black
# cardParts                                                             None
# colorIdentity                                                            U
# colorIndicator                                                        None
# colors                                                                   U
# defense                                                               None
# duelDeck                                                              None
# edhrecRank                                                         14251.0
# edhrecSaltiness                                                        0.6
# faceConvertedManaCost                                                  NaN
# faceFlavorName                                                        None
# faceManaValue                                                          NaN
# faceName                                                              None
# finishes                                                     nonfoil, foil
# flavorName                                                            None
# flavorText                                                            None
# frameEffects                                                          None
# frameVersion                                                          2015
# hand                                                                  None
# hasAlternativeDeckLimit                                               None
# hasContentWarning                                                     None
# hasFoil                                                               True
# hasNonFoil                                                            True
# isAlternative                                                         None
# isFullArt                                                             None
# isFunny                                                               None
# isGameChanger                                                         None
# isOnlineOnly                                                          None
# isOversized                                                           None
# isPromo                                                               None
# isRebalanced                                                          None
# isReprint                                                             True
# isReserved                                                            None
# isStarter                                                             None
# isStorySpotlight                                                      None
# isTextless                                                            None
# isTimeshifted                                                         None
# keywords                                                           Enchant
# language                                                           English
# layout                                                              normal
# leadershipSkills                                                      None
# life                                                                  None
# loyalty                                                               None
# manaCost                                                         {1}{U}{U}
# manaValue                                                              3.0
# name                                                         Charmed Sleep
# number                                                                  50
# originalPrintings                                                     None
# originalReleaseDate                                                   None
# originalText                                                          None
# originalType                                                          None
# otherFaceIds                                                          None
# power                                                                 None
# printings                                         AFR, BLB, ELD, HBG, PLST
# promoTypes                                                            None
# rarity                                                              common
# rebalancedPrintings                                                   None
# relatedCards                                                          None
# securityStamp                                                         None
# setCode                                                                AFR
# side                                                                  None
# signature                                                             None
# sourceProducts           {"foil": ["082f4c03-55d8-57a6-9837-ecbfa2726ac...
# subsets                                                               None
# subtypes                                                              Aura
# supertypes
# text                     Enchant creature\nWhen this Aura enters, tap e...
# toughness                                                             None
# type                                                    Enchantment — Aura
# types                                                          Enchantment
# uuid                                  8915342f-a13c-57cd-a477-e96ec7e00f17
# variations                                                            None
# watermark                                                             None
# standard                                                             Legal
#
#                                                                          2
# artist                                                          Alex Brock
# artistIds                             ce381d25-868c-4f13-b1e9-e7cd2f67e994
# asciiName                                                             None
# attractionLights                                                      None
# availability                                            arena, mtgo, paper
# boosterTypes                                                       default
# borderColor                                                          black
# cardParts                                                             None
# colorIdentity                                                            B
# colorIndicator                                                        None
# colors                                                                   B
# defense                                                               None
# duelDeck                                                              None
# edhrecRank                                                         13580.0
# edhrecSaltiness                                                        NaN
# faceConvertedManaCost                                                  NaN
# faceFlavorName                                                        None
# faceManaValue                                                          NaN
# faceName                                                              None
# finishes                                                     nonfoil, foil
# flavorName                                                            None
# flavorText               Unsuccessful vampire hunters often wind up as ...
# frameEffects                                                          None
# frameVersion                                                          2015
# hand                                                                  None
# hasAlternativeDeckLimit                                               None
# hasContentWarning                                                     None
# hasFoil                                                               True
# hasNonFoil                                                            True
# isAlternative                                                         None
# isFullArt                                                             None
# isFunny                                                               None
# isGameChanger                                                         None
# isOnlineOnly                                                          None
# isOversized                                                           None
# isPromo                                                               None
# isRebalanced                                                          None
# isReprint                                                             None
# isReserved                                                            None
# isStarter                                                             None
# isStorySpotlight                                                      None
# isTextless                                                            None
# isTimeshifted                                                         None
# keywords                                                              None
# language                                                           English
# layout                                                              normal
# leadershipSkills                                                      None
# life                                                                  None
# loyalty                                                               None
# manaCost                                                            {2}{B}
# manaValue                                                              3.0
# name                                                         Vampire Spawn
# number                                                                 123
# originalPrintings                                                     None
# originalReleaseDate                                                   None
# originalText                                                          None
# originalType                                                          None
# otherFaceIds                                                          None
# power                                                                    2
# printings                                                    AFR, FDN, HBG
# promoTypes                                                            None
# rarity                                                              common
# rebalancedPrintings                                                   None
# relatedCards                                                          None
# securityStamp                                                         None
# setCode                                                                AFR
# side                                                                  None
# signature                                                             None
# sourceProducts           {"foil": ["082f4c03-55d8-57a6-9837-ecbfa2726ac...
# subsets                                                               None
# subtypes                                                           Vampire
# supertypes
# text                     When this creature enters, each opponent loses...
# toughness                                                                3
# type                                                    Creature — Vampire
# types                                                             Creature
# uuid                                  f77bcd4a-eb30-535b-bf2d-ad5de7273336
# variations                                                            None
# watermark                                                             None
# standard                                                             Legal
